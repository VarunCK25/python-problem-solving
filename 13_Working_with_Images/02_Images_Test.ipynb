# %% [markdown]
# # Mission Overview
#
# Looks like the email reply had two links:
#
# https://drive.google.com/file/d/15YyLqIuGlsCLr4ioKUeHRw8H2QjBNOz2/view
#
# https://drive.google.com/file/d/128MRLNuytoW7dVm6B7AF_cDVMeACyTFk/view
#
# Let's see if we can figure out how to use these images to figure out the next step.
#
# ____

# %% [markdown]
# First we need to get the images to be the correct size so that our paste operation will line up. Then we can use a transparency mask with an alpha value to find the hidden message. We also need to resize the images so that they line up with each other.

# %%
from PIL import Image

# %%
image_link = Image.open('image_link.PNG')

# %%
image_link
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1226x777 at 0x217B4EAB7B8>

# %%
cover = Image.open('cover_image.PNG')

# %%
cover
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1093x693 at 0x217B4F5E0B8>

# %%
image_link.size
# Out:
# (1226, 777)

# %%
cover.size
# Out:
# (1093, 693)

# %%
image_link = image_link.resize((1093, 693))

# %%
image_link.size
# Out:
# (1093, 693)

# %% [markdown]
# Now we can't just paste them over, otherwise we won't see what is underneath, we need to add an alpha value.

# %%
cover.putalpha(200)

# %%
cover
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=1093x693 at 0x217B4F5E0B8>

# %%
image_link.paste(im=cover, box=(0,0), mask=cover)

# %%
image_link
# Out:
# <PIL.Image.Image image mode=RGBA size=1093x693 at 0x217B4F2C518>

# %% [markdown]
# It looks like the link to visit is: https://goo.gl/LDo5Nt

# %% [markdown]
# ## Thank You!
